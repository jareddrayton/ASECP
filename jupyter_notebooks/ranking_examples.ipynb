# %%
import math
import random
import matplotlib.pyplot as plt

individuals = 1000

# Exponential ranking using Eiben

probabilities = []

for i in range(1, individuals+1):
    prob = (1.0 - (math.e ** - i)) / (individuals -1)

    probabilities.append(prob)

#print(probabilities)
print(sum(probabilities))

fig, ax = plt.subplots()
ax.plot(probabilities)
plt.show()
# Out:
# 1.0004184417348496

# %%
# Linear rankign as given in Eiben

selection_pressure = 2.0  # This can be in the range 1.0 < x <= 2.0

s = 1.5
probabilities = []

for i in range(individuals):
    prob = (2 - s) / individuals + (2.0 * i * (s - 1)) / (individuals * (individuals - 1))

    probabilities.append(prob)
    #print(i, prob)

print(sum(probabilities))

fig, ax = plt.subplots()
ax.plot(probabilities)
plt.show()
# Out:
# 1.0

# %%
# Exponential ranking as given in ``A Comparison of Selection Schemes used in Genetic Algorithms pg 34

c = 0.95

individuals = 150

probabilities = []

for i in range(1, individuals+1):
    prob = ((c - 1) / ((c ** individuals) - 1)) * (c ** (individuals - i))

    probabilities.append(prob)

print(sum(probabilities))

fig, ax = plt.subplots()
ax.plot(probabilities)
plt.show()
# Out:
# 1.0000000000000002
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      12     probabilities.append(prob)
#      14 print(sum(probabilities))
# ---> 16 fig, ax = plt.subplots()
#      17 ax.plot(probabilities)
#      18 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# Square ranking as given in Evolutionary computation Volume 1 page 188

B = 2 # 1 - 2
A = 2 - B

individuals = 10

c = (B-A) * individuals * (2 * individuals - 1) / ((6 * (individuals - 1)) + (individuals * A))  #0.5 

print(c)

print(A/c)
print(B/c)

probabilities = []



for i in range(individuals):
    print(A + ((i ** 2)/(individuals - 1)**2) * (B - A), A + ((i ** 2)/(individuals - 1)**2) * (B - A)  / c)

    prob = A + ((i ** 2)/(individuals - 1)**2) * (B - A)  / c

    probabilities.append(prob)

print(probabilities)
print(sum(probabilities))

fig, ax = plt.subplots()
ax.plot(probabilities)
plt.savefig(fname="epp.pdf", format="pdf")
# Out:
# 7.037037037037037
# 0.0
# 0.28421052631578947
# 0.0 0.0
# 0.024691358024691357 0.003508771929824561
# 0.09876543209876543 0.014035087719298244
# 0.2222222222222222 0.03157894736842105
# 0.3950617283950617 0.05614035087719298
# 0.6172839506172839 0.08771929824561403
# 0.8888888888888888 0.1263157894736842
# 1.2098765432098766 0.17192982456140352
# 1.5802469135802468 0.2245614035087719
# 2.0 0.28421052631578947
# [0.0, 0.003508771929824561, 0.014035087719298244, 0.03157894736842105, 0.05614035087719298, 0.08771929824561403, 0.1263157894736842, 0.17192982456140352, 0.2245614035087719, 0.28421052631578947]
# 1.0

# %%
# Square ranking as given in Evolutionary computation Volume 1 page 188
import seaborn as sns

B = 2 # 1 - 2
A = 2 - B

individuals = 150

c = (B-A) * individuals * (2 * individuals - 1) / ((6 * (individuals - 1)) + (individuals * A))  #0.5 

print(c)

print(A/c)
print(B/c)

probabilities = []

for i in range(individuals):
    print(A + ((i ** 2)/(individuals - 1)**2) * (B - A), A + ((i ** 2)/(individuals - 1)**2) * (B - A)  / c)

    prob = A + ((i ** 2)/(individuals - 1)**2) * (B - A)  / c

    probabilities.append(prob)

print(probabilities)
print(sum(probabilities))

sns.set_style("darkgrid")
fig, ax = plt.subplots()
ax.plot(probabilities)
ax.set_xlabel("Individual Rank")
097394, 0.000324122915310543, 0.00035913896433301167, 0.0003959507081771453, 0.0004345581468429441, 0.00047496128033040785, 0.0005171601086395367, 0.0005611546317703306, 0.0006069448497227896, 0.0006545307624969137, 0.0007039123700927028, 0.000755089672510157, 0.0008080626697492761, 0.0008628313618100604, 0.0009193957486925097, 0.0009777558303966241, 0.0010379116069224035, 0.001099863078269848, 0.0011636102444389576, 0.0012291531054297322, 0.001296491661242172, 0.0013656259118762766, 0.0014365558573320467, 0.0015092814976094813, 0.0015838028327085812, 0.0016601198626293463, 0.0017382325873717764, 0.0018181410069358713, 0.0018998451213216314, 0.0019833449305290568, 0.002068640434558147, 0.0021557316334089023, 0.0022446185270813225, 0.002335301115575408, 0.0024277793988911585, 0.002522053377028574, 0.0026181230499876546, 0.0027159884177684005, 0.002815649480370811, 0.002917106237794887, 0.003020358690040628, 0.0031254068371080338, 0.0032322506789971045, 0.0033408902157078405, 0.0034513254472402417, 0.0035635563735943077, 0.003677582994770039, 0.003793405310767435, 0.003911023321586497, 0.004030437027227223, 0.004151646427689614, 0.00427465152297367, 0.004399452313079392, 0.004526048798006779, 0.00465444097775583, 0.004784628852326547, 0.004916612421718929, 0.005050391685932976, 0.005185966644968688, 0.005323337298826065, 0.0054625036475051065, 0.0056034656910058135, 0.005746223429328187, 0.0058907768624722225, 0.006037125990437925, 0.006185270813225292, 0.006335211330834325, 0.006486947543265023, 0.006640479450517385, 0.006795807052591412, 0.0069529303494871054, 0.007111849341204462, 0.007272564027743485, 0.007435074409104173, 0.007599380485286526, 0.007765482256290544, 0.007933379722116227, 0.008103072882763573, 0.008274561738232588, 0.008447846288523266, 0.00862292653363561, 0.008799802473569616, 0.00897847410832529, 0.00915894143790263, 0.009341204462301632, 0.009525263181522301, 0.009711117595564634, 0.009898767704428633, 0.010088213508114296, 0.010279455006621625, 0.010472492199950618, 0.010667325088101276, 0.010863953671073602, 0.011062377948867592, 0.011262597921483245, 0.011464613588920564, 0.011668424951179548, 0.011874032008260198, 0.012081434760162511, 0.012290633206886491, 0.012501627348432135, 0.012714417184799444, 0.012929002715988418, 0.013145383941999057, 0.013363560862831362, 0.013583533478485333, 0.013805301788960967, 0.014028865794258267, 0.01425422549437723, 0.014481380889317861, 0.014710331979080156, 0.014941078763664116, 0.01517362124306974, 0.01540795941729703, 0.015644093286345986, 0.015882022850216608, 0.01612174810890889, 0.016363269062422844, 0.016606585710758456, 0.016851698053915738, 0.01709860609189468, 0.017347309824695293, 0.01759780925231757, 0.01785010437476151, 0.018104195192027116, 0.018360081704114385, 0.01861776391102332, 0.018877241812753923, 0.019138515409306188, 0.01940158470068012, 0.019666449686875715, 0.019933110367892977]
# 1.0

# %% [markdown]
# $$ Pr_{sq_rank}(i) = \frac{\alpha + (rank_{i}^{2} / (\mu - 1)^{2}) (\beta - \alpha) } {c} $$

# %% [markdown]
# $$ c = \frac{ (\beta - \alpha)\mu(2\mu - 1)}{6(\mu - 1) + \mu\alpha} $$

# %%
# Geometric ranking as given in Evolutionary computation Volume 1

probabilities = []

individuals = 100

A = 0.5 # 0.0 < A < 1.0

for i in range(individuals):
    prob = A * (1-A) ** (individuals-1-i)

    probabilities.append(prob)



print(sum(probabilities))

fig, ax = plt.subplots()
ax.plot(probabilities)
plt.show()
# Out:
# 1.0
