# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import random
import scipy.stats
import numpy as np

a = [random.gauss(0, 0.5) for x in range(200)]

lower_limit = -2

upper_limit = 4

diff = abs(lower_limit - upper_limit)

print(diff)

mean = 0
standard_deviation = 0.5

# mutation values will be drawn from a gaussian distrubution with a mean of 0 and a standard deviation that is scaled

x_values = np.arange(-5, 5, 0.1)
y_values = scipy.stats.norm(mean, standard_deviation)

plt.axvline(x=standard_deviation)
plt.axvline(x=-1*standard_deviation)
plt.plot(x_values, y_values.pdf(x_values))
# Out:
# 6
# <img src="data:image/png;base64,..." width="640">
