# %%
import matplotlib.pyplot as plt

with open('..\data\Primary4.wav.PRT.Gen20.Pop100.Mut0.15.Sd0.15.hz.SSD.id01\Minimum.txt', 'r') as f:
    a = [float(x.strip()) for x in f.readlines()]
    
with open('..\data\Primary4.wav.PRT.Gen20.Pop100.Mut0.15.Sd0.15.hz.SSD.id02\Minimum.txt', 'r') as f:
    b = [float(x.strip()) for x in f.readlines()]

def performance_graph(average_fitness, minimum_fitness, generation_size):
    plt.plot(average_fitness, 'k', label='Mean Fitness')
    plt.plot(minimum_fitness, 'k--', label='Minimum Fitness')
    plt.axis([0, generation_size, 0, max(average_fitness)])
    plt.xlabel('Generation_size')
    plt.ylabel('Fitness')
    plt.legend()
    plt.show()
    #plt.savefig("{}/Performance Graph".format(directory))
    
performance_graph(a, b, 20)

with open('..\data\Primary4.wav.PRT.Gen40.Pop100.Mut0.15.Sd0.15.hz.SSD.id01\Minimum.txt', 'r') as f:
    c = [float(x.strip()) for x in f.readlines()]

def performance_graph_2(c, generation_size):
    #plt.plot(average_fitness, 'k', label='Mean Fitness')
    plt.plot(c, 'k--', label='Minimum Fitness')
    #plt.axis([0, generation_size, 0, max(c)])
    plt.xlabel('Generation_size')
    plt.ylabel('Fitness')
    plt.legend()
    plt.show()
    
performance_graph_2(c, 40)

with open('..\data\Primary6.wav.PRT.Gen40.Pop100.Mut0.15.Sd0.15.hz.SSD.id01\Minimum.txt', 'r') as f:
    d = [float(x.strip()) for x in f.readlines()]

def performance_graph_3(c, generation_size):
    #plt.plot(average_fitness, 'k', label='Mean Fitness')
    plt.plot(c, 'k--', label='Minimum Fitness')
    #plt.axis([0, generation_size, 0, max(c)])
    plt.xlabel('Generation_size')
    plt.ylabel('Fitness')
    plt.legend()
    plt.show()
    
performance_graph_3(d, 40)

with open('..\data\Primary1.wav.PRT.Gen40.Pop100.Mut0.15.Sd0.15.hz.SSD.id01\Minimum.txt', 'r') as f:
    e = [float(x.strip()) for x in f.readlines()]

def performance_graph_4(c, generation_size):
    #plt.plot(average_fitness, 'k', label='Mean Fitness')
    plt.plot(c, 'k--', label='Minimum Fitness')
    #plt.axis([0, generation_size, 0, max(c)])
    plt.xlabel('Generation_size')
    plt.ylabel('Fitness')
    plt.legend()
    plt.show()
    
performance_graph_4(e, 40)
