# %%
import math
import random
import matplotlib.pyplot as plt

individuals = 1000

# Exponential ranking using Eiben

probabilities = []

# Square ranking as given in Evolutionary computation Volume 1 page 188

B = 2 # 1 - 2
A = 2 - B

individuals = 10

c = (B-A) * individuals * (2 * individuals - 1) / ((6 * (individuals - 1)) + (individuals * A))  #0.5 

print(c)

print(A/c)
print(B/c)


for i in range(individuals):
    print(A + ((i ** 2)/(individuals - 1)**2) * (B - A), A + ((i ** 2)/(individuals - 1)**2) * (B - A)  / c)

    prob = A + ((i ** 2)/(individuals - 1)**2) * (B - A)  / c

    probabilities.append(prob)

print(probabilities)
print(sum(probabilities))

fig, ax = plt.subplots()
ax.plot(probabilities)
plt.show()
# Out:
# 7.037037037037037
# 0.0
# 0.28421052631578947
# 0.0 0.0
# 0.024691358024691357 0.003508771929824561
# 0.09876543209876543 0.014035087719298244
# 0.2222222222222222 0.03157894736842105
# 0.3950617283950617 0.05614035087719298
# 0.6172839506172839 0.08771929824561403
# 0.8888888888888888 0.1263157894736842
# 1.2098765432098766 0.17192982456140352
# 1.5802469135802468 0.2245614035087719
# 2.0 0.28421052631578947
# [0.0, 0.003508771929824561, 0.014035087719298244, 0.03157894736842105, 0.05614035087719298, 0.08771929824561403, 0.1263157894736842, 0.17192982456140352, 0.2245614035087719, 0.28421052631578947]
# 1.0

# %% [markdown]
# $$ Pr_{sq_rank}(i) = \frac{\alpha + (rank_{i}^{2} / (\mu - 1)^{2}) (\beta - \alpha) } {c} $$

# %% [markdown]
# $$ c = \frac{ (\beta - \alpha)\mu(2\mu - 1)}{6(\mu - 1) + \mu\alpha} $$

# %%
# Square ranking as given in Evolutionary computation Volume 1 page 188

B = 2 # 1 - 2
A = 2 - B

individuals = 10

c_control = (B-A) * individuals * (2 * individuals - 1) / ((6 * (individuals - 1)) + (individuals * A))  

c_test = individuals * (2 * individuals - 1) / (6 * (individuals - 1))

print(A, B)

print("Normalisation factor", c_control)
print("Normalisation factor", c_test)

prob_control = []
prob_test = []


for i in range(1, individuals+1):

    prob_c = A + ((i ** 2)/(individuals - 1)**2) * (B - A)  / c_control

    prob_control.append(prob_c)
    
    prob_t = ((i ** 2)/(individuals - 1)**2)   / c_test
    
    prob_test.append(prob_t)
    
    
print(prob_control)
print(sum(prob_control))

print(prob_test)
print(sum(prob_test))



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4.5))

ax1.plot(prob_control)
ax2.plot(prob_test)
plt.show()
# Out:
# 0 2
# Normalisation factor 7.037037037037037
# Normalisation factor 285.0
# [0.003508771929824561, 0.014035087719298244, 0.03157894736842105, 0.05614035087719298, 0.08771929824561403, 0.1263157894736842, 0.17192982456140352, 0.2245614035087719, 0.28421052631578947, 0.3508771929824561]
# 1.3508771929824561
# [4.331817197314273e-05, 0.00017327268789257093, 0.0003898635477582846, 0.0006930907515702837, 0.0010829542993285683, 0.0015594541910331384, 0.002122590426683994, 0.002772363006281135, 0.0035087719298245615, 0.004331817197314273]
# 0.016677496209659953

# %% [markdown]
# $$ Pr_{sqrank}(i) = \frac{rank(i)^{2} / (\mu - 1)^{2}} {c} $$

# %% [markdown]
# $$ c = \frac{\mu(2\mu - 1)}{6(\mu - 1)} $$
